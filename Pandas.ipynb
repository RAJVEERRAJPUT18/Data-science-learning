# %%
import pandas as pd

# %%
info={
    "name": ["Raaz","nikhil","neeraj"],
    "cgpa": [8.24,7.8,9.2]
}
df=pd.DataFrame(info)# info store as data frame
print(df)
# Out:
#      name  cgpa
# 0    Raaz  8.24
# 1  nikhil  7.80
# 2  neeraj  9.20

# %%
df
# Out:
#      name  cgpa
# 0    Raaz  8.24
# 1  nikhil  7.80
# 2  neeraj  9.20

# %%
# creating series 
s=pd.Series([1,2,3,4,5])
print(s)
print(type(s))
# label ko ek trike se indexing smjh skte h 
# hmme value ko index ki help se bhi print kr skte h
print(s[1])
print(s[2])
print(s[3])
print(s[4])
print(s[0])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>
# 2
# 3
# 4
# 5
# 1
